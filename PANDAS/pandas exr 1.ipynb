# %% [markdown]
# ### Pandas exercise 1

# %%
import pandas as pd

# %% [markdown]
# ### 1

# %%
df=pd.read_csv('titanic3.csv')
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %% [markdown]
# ### 2

# %%
passengers1=df[df['pclass']==1]
count_passengers1=passengers1.shape[0]
count_passengers1
# Out:
# 323

# %% [markdown]
# ### 3

# %%
df['is_alone']=(df['sibsp']+df['parch'])==0
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest  is_alone
# ...

# %% [markdown]
# ### 4

# %%
mean_age=df.groupby('pclass')['age'].mean()
mean_age
# Out:
# pclass
# 1    39.159930
# 2    29.506705
# 3    24.816367
# Name: age, dtype: float64

# %% [markdown]
# ### 5

# %%
df.value_counts=df['fare'].value_counts(sort=True)
df.head(10)
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5       1         1                              Anderson, Mr. Harry    male
# 6       1         1                Andrews, Miss. Kornelia Theodosia  female
# 7       1         0                           Andrews, Mr. Thomas Jr    male
# 8       1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9       1         0                          Artagaveytia, Mr. Ramon    male
#
#      age  sibsp  parch    ticket      fare    cabin embarked boat   body  \
# ...

# %% [markdown]
# ### 6

# %%
df['fare_category']=pd.cut(df['fare'],bins=[0,10,50,float('inf')],labels=['cheap','moderate','expensive'],right=False)
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest  is_alone fare_category
# ...

# %% [markdown]
# ### 7

# %%
male_survived=df[(df['sex']=='male')&(df['survived']==1)]
male_survived
# Out:
#       pclass  survived                                  name   sex    age  \
# 1          1         1        Allison, Master. Hudson Trevor  male   0.92
# 5          1         1                   Anderson, Mr. Harry  male  48.00
# 14         1         1  Barkworth, Mr. Algernon Henry Wilson  male  80.00
# 20         1         1         Beckwith, Mr. Richard Leonard  male  37.00
# 22         1         1                 Behr, Mr. Karl Howell  male  26.00
# ...      ...       ...                                   ...   ...    ...
# 1238       3         1            Tenglin, Mr. Gunnar Isidor  male  25.00
# 1240       3         1       Thomas, Master. Assad Alexander  male   0.42
# 1254       3         1          Tornquist, Mr. William Henry  male  25.00
# 1256       3         1        Touma, Master. Georges Youssef  male   7.00
# 1277       3         1                  Vartanian, Mr. David  male  22.00
#
#       sibsp  parch  ticket      fare    cabin embarked   boat  body  \
# ...

# %% [markdown]
# ### 8

# %%
df=pd.read_csv('titanic3.csv')
df=df.drop(columns=['cabin'])
df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare embarked boat   body  \
# 0  29.00      0      0   24160  211.3375        S    2    NaN
# 1   0.92      1      2  113781  151.5500        S   11    NaN
# 2   2.00      1      2  113781  151.5500        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# ...
